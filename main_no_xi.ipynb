# %%
import os
import json
import torch
import torch.optim as optim
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fast')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def fourier_residual(t, theta):
    """
    Compute the residual f_theta(t) for the Fourier series ansatz:
    x̃(t) = α sin(ω t)² + β sin(2 ω t)² + γ sin(3 ω t)²
    with parameters theta = (ω, α, β, γ)
    """
    omega, alpha, beta, gamma = theta

    sin_omega = torch.sin(omega * t)
    sin_2omega = torch.sin(2 * omega * t) 
    sin_3omega = torch.sin(3 * omega * t)
    
    x_t = alpha * sin_omega**2 + beta * sin_2omega**2 + gamma * sin_3omega**2

    factor1 = x_t - 1.0
    term_sin2 = sin_omega**2
    term_sin4 = sin_omega**4
    term_sin2_3 = sin_3omega**2

    factor2 = (2 * alpha * term_sin2 - alpha
               - 32 * beta * term_sin4 + 32 * beta * term_sin2 - 4 * beta
               + 18 * gamma * term_sin2_3 - 9 * gamma)

    f_t = 2 * omega**2 * factor1 * factor2 + x_t - x_t**2
    return f_t

def optimize_theta_for_k(k_val, N=100, n_iter=2000, lr=1e-3, print_every=1000):
    """
    Optimize Fourier series parameters theta = (omega, alpha, beta, gamma)
    for given K value to minimize squared error
    """
    t_points = torch.linspace(0, 5 * np.pi, N, device=device)
    
    theta = torch.tensor([1.0, k_val, k_val/2, k_val/4], device=device, requires_grad=True)
    
    optimizer = optim.Adam([theta], lr=lr)
    
    best_loss = float('inf')
    best_theta = None
    
    for it in range(n_iter):
        optimizer.zero_grad()
        f_vals = fourier_residual(t_points, theta)
        loss = torch.mean((f_vals - k_val)**2)
        loss.backward()
        optimizer.step()
        
        if loss.item() < best_loss:
            best_loss = loss.item()
            best_theta = theta.detach().clone()
        
        if (it+1) % print_every == 0:
            print(f"[K = {k_val:.3f}] Iter {it+1:4d}: loss = {loss.item():.4e}   theta = {theta.data.cpu().numpy()}")
    
    return best_theta, best_loss

k_example = 0.1
best_theta, best_loss = optimize_theta_for_k(k_example)
# Out:
# [K = 0.100] Iter 1000: loss = 7.5410e-03   theta = [9.26802042e-01 4.86423713e-02 2.30088375e-03 2.83809291e-04]
# [K = 0.100] Iter 2000: loss = 2.3962e-03   theta = [ 6.65379923e-01  1.47228815e-01 -4.19663166e-04  6.00195965e-04]

# %%
# Compare Fourier series model with a Runge-Kutta solution

def runge_kutta_ode(k, dt=1e-6, T=5*np.pi, epsilon=1e-8):
    """
    Solve the original ODE using RK4:
    (1-x) x'' - x² + x = k
    
    Initial conditions: x(0)=0, x'(0)=0
    """
    N_steps = int(T / dt) + 1
    t = np.linspace(0, T, N_steps)
    x = np.zeros(N_steps)
    v = np.zeros(N_steps)  # velocity = x'
    
    def f(x, v):
        denom = 1 - x
        if np.abs(denom) < epsilon:
            denom = np.sign(denom) * epsilon
        return (k + x**2 - x) / denom
    
    for i in range(N_steps-1):
        k1x = v[i]
        k1v = f(x[i], v[i])
        
        k2x = v[i] + 0.5 * dt * k1v
        k2v = f(x[i] + 0.5 * dt * k1x, v[i] + 0.5 * dt * k1v)
        
        k3x = v[i] + 0.5 * dt * k2v
        k3v = f(x[i] + 0.5 * dt * k2x, v[i] + 0.5 * dt * k2v)
        
        k4x = v[i] + dt * k3v
        k4v = f(x[i] + dt * k3x, v[i] + dt * k3v)
        
        x[i+1] = x[i] + dt/6 * (k1x + 2*k2x + 2*k3x + k4x)
        v[i+1] = v[i] + dt/6 * (k1v + 2*k2v + 2*k3v + k4v)
        
    return t, x

def fourier_series_solution(t, theta):
    """
    Compute Fourier series x̃(t) = α sin(ω t)² + β sin(2 ω t)² + γ sin(3 ω t)²
    """
    omega, alpha, beta, gamma = theta
    return (alpha * torch.sin(omega * t)**2 +
            beta * torch.sin(2 * omega * t)**2 +
            gamma * torch.sin(3 * omega * t)**2)

# %%
# Create comparison plots for different xi values (4 vertically aligned plots)
xi_comparison_values = [0.1, 0.5, 1.0, 4.0]
k_comparison_values = [0.15, 0.1, 0.05]  # Reversed to match second code order

# Store results for comparison plots
results = {
    'xi_values': xi_comparison_values,
    'k_values': k_comparison_values,
    't_rk': [], 'x_rk': [],
    't_fourier': [], 'x_fourier': []
}

# Create figure with 4 subplots vertically aligned
fig, axes = plt.subplots(4, 1, figsize=(10, 20), dpi=300)

# Colors for plotting
light_colors = ['#7fbfff', '#ffbf7f', '#7fdf7f']  # Lighter versions
normal_colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Standard colors

print("\nGenerating comparison plots for different xi values...")

for i, xi_val in enumerate(xi_comparison_values):
    ax = axes[i]
    
    for j, k_val in enumerate(k_comparison_values):
        # RK4 solution
        t_rk, x_rk = runge_kutta_ode(k_val, xi_val, dt=1e-5, T=5*np.pi)
        
        # Fourier solution
        print(f"Optimizing for K={k_val:.3f}, ξ={xi_val:.3f}")
        best_theta, _ = optimize_theta_for_k_xi(k_val, xi_val, n_iter=10000, lr=3e-4, print_every=1000)
        t_fourier = torch.linspace(0, 5 * np.pi, 100, device=device)
        x_fourier = fourier_series_solution(t_fourier, best_theta).detach().cpu().numpy()
        
        # Plot Fourier solution (solid line)
        ax.plot(t_fourier.cpu().numpy(), x_fourier, '-', linewidth=2,
                color=light_colors[j], label=f'Fourier (K={k_val})')
        
        # Plot RK4 solution (dashed line)
        ax.plot(t_rk[::100], x_rk[::100], '--', linewidth=2,
                color=normal_colors[j], label=f'RK4 (K={k_val})')
    
    # Formatting
    ax.set_title(f'ξ = {xi_val}', fontsize=14)
    ax.set_xlabel('Time (t)', fontsize=14)
    ax.set_ylabel('x(t)', fontsize=14)
    ax.grid(True, alpha=0.6)
    ax.legend(fontsize=14, loc='upper right')
    ax.set_xlim(0, 5*np.pi)

plt.tight_layout()
plt.savefig('figs/comparison_xi_solutions_vertical.pdf', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# [K = 0.150] Iter 1000: loss = 1.6188e-02   theta = [9.09084653e-01 8.10617953e-02 3.21608876e-03 1.63031782e-04]
# [K = 0.050] Iter 3000: loss = 6.0624e-09   theta = [4.86404529e-01 1.05675889e-01 4.80843715e-05 6.30218017e-07]
# [K = 0.050] Iter 4000: loss = 1.6798e-15   theta = [ 4.85832593e-01  1.05689632e-01  5.81976211e-05 -5.83580215e-07]
# [K = 0.050] Iter 5000: loss = 1.5793e-15   theta = [ 4.85832520e-01  1.05689634e-01  5.81989578e-05 -5.83741239e-07]
# [K = 0.050] Iter 6000: loss = 1.5793e-15   theta = [ 4.85832520e-01  1.05689634e-01  5.81989578e-05 -5.83741239e-07]
# [K = 0.050] Iter 7000: loss = 1.5793e-15   theta = [ 4.85832520e-01  1.05689634e-01  5.81989578e-05 -5.83741239e-07]
# [K = 0.050] Iter 8000: loss = 1.5793e-15   theta = [ 4.85832520e-01  1.05689634e-01  5.81989578e-05 -5.83741239e-07]
# [K = 0.050] Iter 9000: loss = 1.5793e-15   theta = [ 4.85832520e-01  1.05689634e-01  5.81989578e-05 -5.83741239e-07]
# [K = 0.050] Iter 10000: loss = 1.5793e-15   theta = [ 4.85832520e-01  1.05689634e-01  5.81989578e-05 -5.83741239e-07]

# %%
# Plot absolute error between Fourier and RK4 solutions
plt.figure(figsize=(10, 5), dpi=300)

for i, k in enumerate(k_values):
    x_fourier_interp = np.interp(results['t_rk'][i], results['t_fourier'][i], results['x_fourier'][i])
    error = np.abs(results['x_rk'][i] - x_fourier_interp)
    plt.plot(results['t_rk'][i], error, '-', linewidth=2,
             color=normal_colors[i], label=f'Error (K={k})', alpha=0.8)

plt.xlabel('Time (t)', fontsize=14)
plt.ylabel('Absolute Error', fontsize=14)
plt.legend(fontsize=14, loc='upper right')
plt.grid(True, alpha=0.6)
plt.yscale('log')
plt.tight_layout()
plt.savefig('figs/error_plot.pdf', bbox_inches='tight', dpi=300)
plt.show()

# %%
# Load or compute theta values for different k
k_star = 0.201
num_k = 100
karpathy_constant = 3e-4
file_path = 'data/theta_values.npz'

if os.path.exists(file_path):
    print("Loading precomputed theta and K values...")
    data = np.load(file_path)
    theta_values = data['theta_values']
    k_values = data['k_values']
    print("Loaded theta and K values from theta_values.npz")
else:
    k_values = np.linspace(0.002, k_star, num_k)
    theta_values = []

    print("\nOptimizing theta for different values of k...")
    for k_val in k_values:
        print(f"\nOptimizing theta for K = {k_val:.3f}...")
        theta_opt_k, _ = optimize_theta_for_k(k_val, n_iter=10000, lr=karpathy_constant, print_every=1000)
        theta_values.append(theta_opt_k.cpu().numpy())
    theta_values = np.array(theta_values)

    np.savez(file_path, 
             theta_values=theta_values,
             k_values=k_values)
    print("Saved theta and K values to theta_values.npz")
# Out:
# Loading precomputed theta and K values...
# Loaded theta and K values from theta_values.npz

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(1, 64),
            nn.GELU(),
            nn.Linear(64, 128),
            nn.GELU(),
            nn.Linear(128, 64),
            nn.GELU(),
            nn.Linear(64, 32),
            nn.GELU(),
            nn.Linear(32, 4)
        )
    
    def forward(self, x):
        return self.network(x)
    
model = Net().to(device)
k_tensor = torch.tensor(k_values, device=device).unsqueeze(1)  # Shape: (num_k,1)
theta_tensor = torch.tensor(theta_values, device=device) # Shape: (num_k,4)

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)

n_epochs = 500_000
patience = 10_000
best_loss = float('inf')
epochs_without_improvement = 0
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=n_epochs)

for epoch in range(1, n_epochs + 1):
    optimizer.zero_grad()
    predictions = model(k_tensor).squeeze(1)  # shape: (num_k, 4)
    loss = torch.mean((predictions - theta_tensor) ** 2)
    loss.backward()
    optimizer.step()
    scheduler.step()

    if loss.item() < best_loss:
        best_loss = loss.item()
        epochs_without_improvement = 0
    else:
        epochs_without_improvement += 1

    if epoch % 1000 == 0:
        print(f"Epoch {epoch:4d}, Loss: {loss.item():.4e}")
    
    if epochs_without_improvement >= patience:
        print(f"Early stopping at epoch {epoch} due to lack of improvement.")
        break

# %%
MODEL_DIR = "saved_models"

MODEL_PATH, PARAMS_PATH = [
    os.path.join(MODEL_DIR, name) for name in (
        "model.pt",
        "params.json"
    )
]

def save_model_and_params():
    os.makedirs(MODEL_DIR, exist_ok=True)
    torch.save(model.state_dict(), MODEL_PATH)

    params = {
        'k_values': k_values.tolist(),
        'theta_values': theta_tensor.tolist()
    }
    with open(PARAMS_PATH, 'w') as f:
        json.dump(params, f)

def load_model_and_params():
    needed_files = [MODEL_PATH, PARAMS_PATH]
    if not all(os.path.exists(f) for f in needed_files):
        return False

    model.load_state_dict(torch.load(MODEL_PATH))
    model.eval()

    with open(PARAMS_PATH, 'r') as f:
        params = json.load(f)
        global k_values, theta_tensor
        k_values = torch.tensor(params['k_values'])
        theta_tensor = torch.tensor(params['theta_values'])
    
    return True

if not load_model_and_params():
    save_model_and_params()

# %%
plt.figure(figsize=(10, 8), dpi=300)
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']
labels = ['ω', 'α', 'β', 'γ']

x_values = k_tensor.cpu().numpy()

with torch.no_grad():
    predictions = model(k_tensor).detach().cpu().numpy()

for i in range(4):
    plt.subplot(2, 2, i + 1)
    plt.grid(True, alpha=0.6)
    plt.plot(x_values, theta_tensor[:, i].cpu().numpy(), 'x', alpha=0.7,
             label=f'Ref. {labels[i]}', markersize=10, color=colors[i])
    plt.plot(x_values, predictions[:, i], '-',
             color=colors[i], label=f'Fitted {labels[i]}', linewidth=1)
    plt.xlabel('K', fontsize=14)
    plt.ylabel(labels[i], fontsize=14)
    plt.xlim(min(x_values) - 0.01, max(x_values) + 0.01)
    if i == 1:
        plt.ylim(-0.05, 0.7)
    elif i == 2:
        plt.ylim(-0.005, 0.06)
    plt.legend(fontsize=14, loc='best')

plt.tight_layout()
plt.savefig('figs/parameters.pdf', bbox_inches='tight', dpi=300)
plt.show()

print("\nFitted parameters for the single model predicting [ω, α, β, γ]:")
for param_name, param_tensor in model.state_dict().items():
    print(f"{param_name} = {param_tensor.cpu().numpy()}")
# Out:
# Fitted parameters for the single model predicting [ω, α, β, γ]:
# network.0.weight = [[-0.73822785]
#  [ 1.19500099]
#  [ 0.09552016]
#  [ 0.42270612]
#  [-1.15533733]
#  [ 1.23778773]
#  [-0.10825211]
#  [ 0.30904758]
#  [-0.81454442]
#  [-0.54980799]
#  [-0.49237707]
#  [-0.55790806]
#  [-0.07659014]
#  [ 0.60556602]
#  [ 0.28616954]
#  [ 1.41100848]
#  [-1.10737037]
#  [-0.70900444]
#  [ 0.57183312]
#  [ 0.49446778]
#  [-1.17112821]
#  [-0.86717226]
#  [-0.94429416]
#  [ 0.72506704]
#  [-0.53189921]
#  [-0.61679866]
#  [-0.94515266]
#  [-1.82654892]
#  [-0.82993146]
#  [-0.84459089]
#  [-0.8881454 ]
#  [ 0.32765034]
#  [ 1.41588955]
#  [ 1.31734234]
#  [ 1.04359613]
#  [-0.3102171 ]
#  [ 1.319366  ]
#  [ 1.31112396]
#  [-1.09689036]
#  [-0.44863802]
#  [ 0.32228236]
#  [-1.04131376]
#  [-0.43101143]
#  [-1.07183376]
#  [-0.49738281]
#  [ 0.01284519]
#  [ 0.06189681]
#  [ 1.00676386]
#  [ 1.25824198]
#  [-1.0089403 ]
#  [-0.40728477]
#  [ 1.101442  ]
#  [ 0.95202611]
#  [ 0.87615281]
#  [-0.54866939]
#  [-1.06327936]
#  [ 1.13655892]
#  [ 0.21555174]
#  [ 0.86070532]
#  [-0.58000504]
#  [-0.89571247]
#  [ 0.51794101]
#  [ 0.48731775]
#  [-0.23837007]]
# network.0.bias = [-0.00144381  0.2715016   0.35802047  0.2429588   0.65484171 -0.32619966
#   0.01496303 -0.25832423  0.49835028 -0.21051145  0.30041816 -0.15606166
#  -0.26590441  0.11618023  0.59455206 -0.53204839  0.53100251  0.20817117
#  -0.14279763  0.11347521  0.34990099  0.01515051  0.01292142  0.78681552
#   0.1882207   0.06801649 -0.15050636 -0.89489411 -0.01755484 -0.01068514
#   0.0100951   0.04217003 -0.58174605  0.29036338  0.34263743 -1.21235275
#  -0.09138504 -0.47131577 -1.06533035  0.52389437 -1.42600985  0.94585662
#   0.06035274  0.13889826  0.06211987 -0.00244545 -0.00750742  0.5927998
#  -0.11422935  0.4497345   0.05135802 -0.07413542 -0.31798802  0.04991683
#   0.54762684  0.67396733  0.1873261   0.65960313  0.20890497  0.01318875
#   0.3126686  -0.07362117 -0.27919653  0.0340314 ]
# network.2.weight = [[-0.10692108 -0.00159233 -0.01889149 ... -0.03328646  0.09193727
#    0.00065108]
#  [-0.03786251 -0.08243213 -0.06819693 ... -0.09860007  0.09967109
#   -0.07407697]
#  [-0.13952557 -0.07417565 -0.04834439 ... -0.12271935  0.05753055
#   -0.09716388]
#  ...
#  [ 0.11719199  0.08091947  0.00614373 ... -0.00886802  0.1015673
#   -0.03247206]
#  [ 0.09713038 -0.05630706 -0.06948127 ... -0.05581692  0.05190385
#   -0.08999   ]
#    1.75965278e-02  7.80057735e-02  7.00925414e-03  4.44266304e-03
#   -4.74782480e-02 -1.30359750e-01 -4.27956744e-04 -5.68268917e-02
#   -5.00267416e-03  1.07601445e-01 -4.68877118e-02  8.54840125e-02
#   -2.92251308e-03 -6.21568617e-03 -5.74040803e-02 -3.59460656e-02
#   -5.48597300e-02 -1.29615700e-01 -4.45376633e-03 -7.79439503e-02
#   -1.02317769e-01 -8.28167678e-03 -1.58724732e-01 -4.77162003e-03]
#  [ 9.15721148e-02  1.28528254e-03 -3.85113906e-02 -1.31015605e-01
#   -6.71225697e-02  2.60711036e-02 -2.13127620e-02 -4.45676404e-02
#    2.42471531e-02 -1.02401266e-01  3.54608319e-03 -2.90339945e-02
#   -1.24829660e-01 -1.75773638e-01  6.71374950e-02 -6.47422530e-02
#    4.30835349e-03  6.90732463e-02  7.58830102e-02 -4.10127909e-02
#   -2.16612461e-03  8.90775326e-05 -5.08269639e-02  2.69100745e-02
#   -1.56320793e-01  8.57997626e-02  3.79178594e-03  4.35547452e-02
#    1.72018561e-02 -1.01852929e-03  8.12099445e-02  1.37089315e-04]]
# network.8.bias = [ 0.0810526   0.02137341 -0.08041431 -0.0713105 ]

# %%
model.eval()

with torch.no_grad():
    predictions = model(k_tensor)

true_values = theta_tensor.cpu().numpy()
pred_values = predictions.cpu().numpy()

x_values = k_tensor.cpu().numpy()
abs_errors = np.abs(true_values - pred_values)

labels = ['ω', 'α', 'β', 'γ']

# Plot errors
plt.figure(figsize=(10, 8), dpi=300)
for i, label in enumerate(labels):
    plt.subplot(2, 2, i + 1)
    plt.plot(x_values, abs_errors[:, i], '-', linewidth=2, markersize=4, color=colors[i])
    plt.xlabel('K', fontsize=14)
    plt.ylabel(f'Absolute Error in {label}', fontsize=14)
    plt.yscale('log')
    plt.grid(True, alpha=0.6)

plt.tight_layout()
plt.savefig('figs/absolute_errors.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import scipy.optimize

def solve_true_amplitude(k):
    """Find nontrivial amplitude A from -A^2 - 2*k*log(1-A)=0 (ignoring A=0)."""
    f = lambda A: -A**2 - 2*k*np.log(1 - A)
    A_low = 1e-6
    A_test = A_low
    while A_test < 0.99 and f(A_test) >= 0:
        A_test *= 1.05
    A_high = A_test
    return scipy.optimize.brentq(f, A_low, A_high)

k_comp = np.linspace(0.002, k_star, 50)
true_amplitudes = []
fourier_amplitudes = []
absolute_errors = []
t_fine = torch.linspace(0, 5 * np.pi, 1000, device=device)

print("\nComparing amplitudes for each K:")
for k in k_comp:
    A_true = solve_true_amplitude(k)
    true_amplitudes.append(A_true)
    
    best_theta, _ = optimize_theta_for_k(k, n_iter=2000, lr=karpathy_constant, print_every=1000)
    x_fourier = fourier_series_solution(t_fine, best_theta).detach().cpu().numpy()
    A_fourier = np.max(x_fourier)
    fourier_amplitudes.append(A_fourier)
    
    abs_err = abs(A_fourier - A_true)
    absolute_errors.append(abs_err)
    
    print(f"K = {k:.3f}: True amplitude = {A_true:.5f}, Fourier amplitude = {A_fourier:.5f}, Absolute error = {abs_err:.5e}")
# Out:
# Comparing amplitudes for each K:
# [K = 0.002] Iter 1000: loss = 3.2119e-06   theta = [9.94493063e-01 7.40371526e-04 2.95598923e-05 5.49169496e-06]
# [K = 0.002] Iter 2000: loss = 3.2112e-06   theta = [9.89903170e-01 7.53967465e-04 2.97419124e-05 5.45882350e-06]
# K = 0.002: True amplitude = 0.00401, Fourier amplitude = 0.00076, Absolute error = 3.24861e-03
# [K = 0.006] Iter 1000: loss = 2.9493e-05   theta = [9.94329697e-01 2.24858093e-03 8.92356342e-05 1.66063847e-05]
# [K = 0.006] Iter 2000: loss = 2.9488e-05   theta = [9.90812321e-01 2.28017511e-03 8.96537396e-05 1.65305352e-05]
# K = 0.006: True amplitude = 0.01220, Fourier amplitude = 0.00230, Absolute error = 9.90029e-03
# [K = 0.010] Iter 1000: loss = 8.2234e-05   theta = [9.93751067e-01 3.76946835e-03 1.48518071e-04 2.76566289e-05]
# [K = 0.010] Iter 2000: loss = 8.2221e-05   theta = [9.90704756e-01 3.81530709e-03 1.49111201e-04 2.75478845e-05]
# K = 0.010: True amplitude = 0.02045, Fourier amplitude = 0.00384, Absolute error = 1.66120e-02
# [K = 0.014] Iter 1000: loss = 1.6141e-04   theta = [9.92998523e-01 5.30558664e-03 2.07426962e-04 3.86377051e-05]
# [K = 0.014] Iter 2000: loss = 1.6138e-04   theta = [9.90148549e-01 5.36590501e-03 2.08182667e-04 3.84956217e-05]
# K = 0.014: True amplitude = 0.02878, Fourier amplitude = 0.00540, Absolute error = 2.33792e-02
# [K = 0.018] Iter 1000: loss = 2.6700e-04   theta = [9.92153673e-01 6.85802931e-03 2.65958920e-04 4.95483307e-05]
# [K = 0.018] Iter 2000: loss = 2.6695e-04   theta = [9.89374671e-01 6.93395153e-03 2.66868179e-04 4.93688454e-05]
# K = 0.018: True amplitude = 0.03719, Fourier amplitude = 0.00698, Absolute error = 3.02022e-02
# [K = 0.022] Iter 1000: loss = 3.9897e-04   theta = [9.91256304e-01 8.42729991e-03 3.24098318e-04 6.03877831e-05]
# [K = 0.022] Iter 2000: loss = 3.9889e-04   theta = [9.88480428e-01 8.52026855e-03 3.25146321e-04 6.01650657e-05]
# K = 0.022: True amplitude = 0.04566, Fourier amplitude = 0.00858, Absolute error = 3.70825e-02
# [K = 0.026] Iter 1000: loss = 5.5730e-04   theta = [9.90329360e-01 1.00135781e-02 3.81820931e-04 7.11552163e-05]
# [K = 0.026] Iter 2000: loss = 5.5718e-04   theta = [9.87514482e-01 1.01252020e-02 3.82984775e-04 7.08833774e-05]
# K = 0.026: True amplitude = 0.05422, Fourier amplitude = 0.01020, Absolute error = 4.40221e-02
# [K = 0.030] Iter 1000: loss = 7.4195e-04   theta = [9.89387752e-01 1.16168229e-02 4.39096134e-04 8.18498443e-05]
# [K = 0.030] Iter 2000: loss = 7.4178e-04   theta = [9.86504496e-01 1.17488335e-02 4.40345097e-04 8.15252707e-05]
# K = 0.030: True amplitude = 0.06285, Fourier amplitude = 0.01183, Absolute error = 5.10235e-02
# [K = 0.034] Iter 1000: loss = 9.5290e-04   theta = [9.88442008e-01 1.32368267e-02 4.95888973e-04 9.24715344e-05]
# [K = 0.034] Iter 2000: loss = 9.5265e-04   theta = [9.85467767e-01 1.33910691e-02 4.97186361e-04 9.20960048e-05]
# K = 0.034: True amplitude = 0.07157, Fourier amplitude = 0.01348, Absolute error = 5.80895e-02
# [K = 0.039] Iter 1000: loss = 1.1901e-03   theta = [9.87499965e-01 1.48732534e-02 5.52162304e-04 1.03021557e-04]
# [K = 0.039] Iter 2000: loss = 1.1898e-03   theta = [9.84415916e-01 1.50516881e-02 5.53468517e-04 1.02606094e-04]
# K = 0.039: True amplitude = 0.08038, Fourier amplitude = 0.01515, Absolute error = 6.52235e-02
# [K = 0.043] Iter 1000: loss = 1.4536e-03   theta = [9.86567634e-01 1.65256697e-02 6.07878888e-04 1.13503300e-04]
# [K = 0.043] Iter 2000: loss = 1.4531e-03   theta = [9.83357195e-01 1.67303746e-02 6.09155500e-04 1.13072600e-04]
# K = 0.043: True amplitude = 0.08927, Fourier amplitude = 0.01684, Absolute error = 7.24278e-02
# [K = 0.047] Iter 1000: loss = 1.7432e-03   theta = [9.85649666e-01 1.81935737e-02 6.63003256e-04 1.23922799e-04]
# [K = 0.047] Iter 2000: loss = 1.7425e-03   theta = [9.82297706e-01 1.84267422e-02 6.64217926e-04 1.23520022e-04]
# K = 0.047: True amplitude = 0.09826, Fourier amplitude = 0.01855, Absolute error = 7.97072e-02
# [K = 0.051] Iter 1000: loss = 2.0590e-03   theta = [9.84749633e-01 1.98764218e-02 7.17503204e-04 1.34289002e-04]
# [K = 0.051] Iter 2000: loss = 2.0581e-03   theta = [9.81242088e-01 2.01403556e-02 7.18635216e-04 1.33980640e-04]
# K = 0.051: True amplitude = 0.10734, Fourier amplitude = 0.02027, Absolute error = 8.70649e-02
# [K = 0.055] Iter 1000: loss = 2.4010e-03   theta = [9.83870205e-01 2.15736527e-02 7.71350794e-04 1.44613735e-04]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=300)

ax1.plot(k_comp, true_amplitudes, '-', linewidth=2, label="Ref. max. deflection")
ax1.plot(k_comp, fourier_amplitudes, '--', linewidth=2, label="Fourier max. deflection")
ax1.set_xlabel("K", fontsize=16)
ax1.set_ylabel("Max. deflection", fontsize=16)
ax1.legend(fontsize=14)
ax1.grid(True, alpha=0.6)

ax2.plot(k_comp, absolute_errors, '-', linewidth=2, label="Absolute Error")
ax2.set_xlabel("K", fontsize=14)
ax2.set_ylabel("Absolute Error", fontsize=14)
ax2.set_yscale('log')
ax2.legend(fontsize=14)
ax2.grid(True, alpha=0.6)

plt.tight_layout()
plt.savefig('figs/amplitude_and_error_comparison.pdf', bbox_inches='tight', dpi=300)
plt.show()
